# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Import The Libraries

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Import numpy and pandas library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import data visualization library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import the dataset

# %%
dataset = pd.read_csv('Salary_Data.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  Estimated Salary  Purchased
# 0    15624510    Male   19             19000          0
# 1    15810944    Male   35             20000          0
# 2    15668575  Female   26             43000          0
# 3    15603246  Female   27             57000          0
# 4    15804002    Male   19             76000          0
# ..        ...     ...  ...               ...        ...
# 395  15691863  Female   46             41000          1
# 396  15706071    Male   51             23000          1
# 397  15654296  Female   50             20000          1
# 398  15755018    Male   36             33000          0
# 399  15594041  Female   49             36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ## Understand the DataSet

# %%
dataset.shape
# Out:
# (400, 5)

# %%
dataset.head()
# Out:
#     User ID  Gender  Age  Estimated Salary  Purchased
# 0  15624510    Male   19             19000          0
# 1  15810944    Male   35             20000          0
# 2  15668575  Female   26             43000          0
# 3  15603246  Female   27             57000          0
# 4  15804002    Male   19             76000          0

# %% [markdown]
# ## Slicing the DataSet

# %%
sales = pd.read_csv("Salary_Data.csv")
sales = sales.drop(['User ID','Gender','Purchased'],axis = 1)
sales.head()
# Out:
#    Age  Estimated Salary
# 0   19             19000
# 1   35             20000
# 2   26             43000
# 3   27             57000
# 4   19             76000

# %%
dataset
# Out:
#       User ID  Gender  Age  Estimated Salary  Purchased
# 0    15624510    Male   19             19000          0
# 1    15810944    Male   35             20000          0
# 2    15668575  Female   26             43000          0
# 3    15603246  Female   27             57000          0
# 4    15804002    Male   19             76000          0
# ..        ...     ...  ...               ...        ...
# 395  15691863  Female   46             41000          1
# 396  15706071    Male   51             23000          1
# 397  15654296  Female   50             20000          1
# 398  15755018    Male   36             33000          0
# 399  15594041  Female   49             36000          1
#
# [400 rows x 5 columns]

# %%
x = dataset.iloc[:,2]

# %%
x.shape
# Out:
# (400,)

# %%
x
# Out:
# array([[19],
#        [35],
#        [26],
#        [27],
#        [19],
#        [27],
#        [27],
#        [32],
#        [25],
#        [35],
#        [26],
#        [26],
#        [20],
#        [32],
#        [18],
#        [29],
#        [47],
#        [45],
#        [46],
#        [48],
#        [45],
#        [47],
#        [48],
#        [45],
#        [46],
#        [47],
#        [49],
#        [47],
#        [29],
#        [31],
#        [31],
#        [27],
#        [21],
#        [28],
#        [27],
#        [35],
#        [33],
#        [30],
#        [26],
#        [27],
#        [27],
#        [33],
#        [35],
#        [30],
#        [28],
#        [23],
#        [25],
#        [27],
#        [30],
#        [31],
#        [24],
#        [18],
#        [29],
#        [35],
#        [27],
#        [24],
#        [23],
#        [28],
#        [22],
#        [32],
#        [27],
#        [25],
#        [23],
#        [32],
#        [59],
#        [24],
# ...

# %%
x = dataset.iloc[:,2].values.reshape(-1,1)

# %%
x.shape
# Out:
# (400, 1)

# %%
x
# Out:
# array([[19],
#        [35],
#        [26],
#        [27],
#        [19],
#        [27],
#        [27],
#        [32],
#        [25],
#        [35],
#        [26],
#        [26],
#        [20],
#        [32],
#        [18],
#        [29],
#        [47],
#        [45],
#        [46],
#        [48],
#        [45],
#        [47],
#        [48],
#        [45],
#        [46],
#        [47],
#        [49],
#        [47],
#        [29],
#        [31],
#        [31],
#        [27],
#        [21],
#        [28],
#        [27],
#        [35],
#        [33],
#        [30],
#        [26],
#        [27],
#        [27],
#        [33],
#        [35],
#        [30],
#        [28],
#        [23],
#        [25],
#        [27],
#        [30],
#        [31],
#        [24],
#        [18],
#        [29],
#        [35],
#        [27],
#        [24],
#        [23],
#        [28],
#        [22],
#        [32],
#        [27],
#        [25],
#        [23],
#        [32],
#        [59],
#        [24],
# ...

# %%
y = dataset.iloc[:,-2].values.reshape(-1,1)

# %%
y.shape
# Out:
# (400, 1)

# %%
y
# Out:
# array([[ 19000],
#        [ 20000],
#        [ 43000],
#        [ 57000],
#        [ 76000],
#        [ 58000],
#        [ 84000],
#        [150000],
#        [ 33000],
#        [ 65000],
#        [ 80000],
#        [ 52000],
#        [ 86000],
#        [ 18000],
#        [ 82000],
#        [ 80000],
#        [ 25000],
#        [ 26000],
#        [ 28000],
#        [ 29000],
#        [ 22000],
#        [ 49000],
#        [ 41000],
#        [ 22000],
#        [ 23000],
#        [ 20000],
#        [ 28000],
#        [ 30000],
#        [ 43000],
#        [ 18000],
#        [ 74000],
#        [137000],
#        [ 16000],
#        [ 44000],
#        [ 90000],
#        [ 27000],
#        [ 28000],
#        [ 49000],
#        [ 72000],
#        [ 31000],
#        [ 17000],
#        [ 51000],
#        [108000],
#        [ 15000],
#        [ 84000],
#        [ 20000],
#        [ 79000],
#        [ 54000],
#        [135000],
#        [ 89000],
#        [ 32000],
#        [ 44000],
# ...

# %%
plt.scatter(x,y)

# %% [markdown]
# ## Divide the data set into training and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=100)

# %%
x_train.shape
# Out:
# (280, 1)

# %%
x_test.shape
# Out:
# (120, 1)

# %%
y_train.shape
# Out:
# (280, 1)

# %%
y_test.shape
# Out:
# (120, 1)

# %% [markdown]
# ## PERFORM THE LINEAR REGRSSION
#
#
# ## Import the function

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %% [markdown]
# ## Train the model

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predict the chaance of admit

# %%
y_pred = lm.predict(x_test)

# %%
y_pred
# Out:
# array([[73477.27206056],
#        [76231.15610133],
#        [68657.97498922],
#        [70723.3880198 ],
#        [67969.50397903],
#        [76919.62711152],
#        [73477.27206056],
#        [70723.3880198 ],
#        [73477.27206056],
#        [65215.61993826],
#        [72100.33004018],
#        [74165.74307075],
#        [71411.85902999],
#        [67969.50397903],
#        [86558.22125419],
#        [81050.45317266],
#        [72788.80105037],
#        [72100.33004018],
#        [69346.44599941],
#        [65904.09094846],
#        [72100.33004018],
#        [64527.14892807],
#        [64527.14892807],
#        [58330.90983635],
#        [86558.22125419],
#        [70034.9170096 ],
#        [63150.20690769],
#        [84492.80822362],
#        [61084.79387712],
#        [76231.15610133],
#        [69346.44599941],
#        [79673.51115228],
#        [76919.62711152],
#        [78985.04014209],
#        [83115.86620324],
#        [85869.750244  ],
#        [67281.03296884],
# ...

# %% [markdown]
# ## Check our prediction

# %%
check = pd.DataFrame(x_test,columns = ['Age'])

# %%
check['Actual Salary']=y_test

# %%
check['Predicted Salary']=y_pred

# %%
check
# Out:
#      Age  Actual Salary  Predicted Salary
# 0     41          52000      73477.272061
# 1     45          32000      76231.156101
# 2     34          43000      68657.974989
# 3     37          93000      70723.388020
# 4     33          60000      67969.503979
# ..   ...            ...               ...
# 115   30          80000      65904.090948
# 116   29          75000      65215.619938
# 117   58          38000      85181.279234
# 118   27         137000      63838.677918
# 119   58         101000      85181.279234
#
# [120 rows x 3 columns]

# %%
plt.scatter(x,y,color = 'blue')
plt.plot(x_test,y_pred,color = 'red')
